# %% [markdown]
# # 2024-03-14
# ## Python Study for PBI Lab Crew

# %% [markdown]
# # Computer 에 대한 이해
#
# **OS? Kernel? shell? python? 뭔데 그게?**
#
# **OS란?? Operating System(OS)**
# <br>
#  컴퓨터 시스템의 핵심 소프트웨어로, 컴퓨터 하드웨어와 응용 프로그램 간의 상호작용을 관리하고 제어하는 역할을 한다.
#
# ![img](https://img1.daumcdn.net/thumb/R1280x0/?scode=mtistory2&fname=https%3A%2F%2Fblog.kakaocdn.net%2Fdn%2FcOkGK5%2FbtsjmCGpJkH%2F6CkSoiCHFJkAiUV1gCKKV1%2Fimg.png)
#
#
# <br><br>
# **커널이란**
# <br>
# 커널(Kernel)은 운영체제(OS) 중 항상 메모리에 올라가 있는 운영체제의 핵심 부분으로써 하드웨어와 응용 프로그램 사이에서 인터페이스를 제공하는 역할을 하며 컴퓨터 자원들을 관리하는 역할을 한다. 즉, 커널은 인터페이스로써 응용 프로그램 수행에 필요한 여러가지 서비스를 제공하고, 여러가지 하드웨어(CPU, 메모리) 등의 리소스를 관리하는 역할을 한다.
#
# 다만 이러한 커널은 항상 컴퓨터 자원들을 바라만 보고 있기에 사용자와의 상호작용은 지원하지 않는다. 따라서 사용자와의 직접전인 상호작용을 위해 프로그램을 제공하게 되는데, 대표적으로 **쉘(Shell)**
# 이라는 명령어 해석기등이 있다.
#
# ![img](https://img1.daumcdn.net/thumb/R1280x0/?scode=mtistory2&fname=https%3A%2F%2Fblog.kakaocdn.net%2Fdn%2Fd3bS7t%2FbtrnW2uPm0N%2FzDF5ZzZe6Bzd8SdQOkYiTK%2Fimg.png)
# ![img](https://images.velog.io/images/byunji_jump/post/3af7c087-52bb-4653-85e6-e74fffa759d1/image.png)
#
# https://minkwon4.tistory.com/295

# %% [markdown]
# **터미널(terminal) :**
#
# -인간과 컴퓨터가 소통하게 해주는 통로, 인터페이스라고 생각하면 쉽다.
#
#
#
# -터미널은 크게 gui 기반 터미널과 텍스트 기반 터미널이 두 가지가 있는데 그중 리눅스 터미널은 텍스트 기반 터미널이다. 터미널은 주로 shell을 이용한다.
#
#
#
# -서버의 로컬 또는 원격으로 접속할 수 있는 콘솔을 구현한 소프트웨어
#
#
#
#
#
# **콘솔(console) :**
#
# -터미널의 일종으로, 시스템 제어를 위한 특수목적 터미널이다.
#
#
#
# -서버의 로컬 장치에서 직접 명령어를 작성할 수 있는 입출력 장치.
#
#
#
# -콘솔이 물리적인 장치라면 터미널은 원격제어 환경까지 포함하는 더 넓은 의미라고 할 수 있다.
#
#
#
# -콘솔 = 물리적 터미널

# %% [markdown]
# **프로그래밍 언어?? 코딩??**
# <br>
#
# 컴파일 언어와 인터프리트 언어
# 　프로그래밍 언어는 일반적으로 고급 언어와 저급 언어로 분류된다. 사람이 이해하기 쉽게 작성된 고급 언어는 컴퓨터가 이해할 수 있는 저급 언어로 변환되어야 한다. 이 과정에서 고급 언어가 저급 언어로 바뀌는 방식에는 주로 컴파일 언어 방식과 인터프리터 언어 방식, 두 가지 방법이 있다.
# <br>
# <br>
# 　먼저 컴파일 언어 방식에 대해 알아보자.<br><br> **컴파일 언어는 소스 코드 전체가 컴파일러에 의해 저급 언어로 변환되는 프로그래밍 언어를 지칭한다.**<br> 여기서 컴파일(compile)은 코드 전체를 저급 언어로 변환하는 과정을 의미하며, 컴파일러(compiler)는 이 과정을 수행하는 도구를 가리킨다. 컴파일러는 개발자가 작성한 소스 코드를 전반적으로 검토하여 문법적 오류가 있는지, 실행 가능한 코드인지 등을 분석하고, 소스 코드를 처음부터 끝까지 저급 언어로 컴파일한다. 이렇게 컴파일러를 통해 저급 언어로 변환된 코드는 목적(object) 코드라고 부른다. 대표적인 컴파일 언어로는 C가 있다.
#
#
#
# ![nn](컴파일.png)
# 고급 언어가 컴파일 방식으로 저급 언어로 변환되는 과정
#
#
# 　<br>**인터프리터 방식은 인터프리터에 의해 소스 코드가 한 줄씩 실행되는 프로그래밍 언어다.** <br>여기서 인터프리터(interpreter)란 소스 코드를 한 줄씩 저급 언어로 변환하여 실행해 주는 도구를 의미한다. 이 방식은 컴퓨터와 대화하듯 소스 코드를 한 줄씩 실행하기 때문에 소스 코드 전체를 저급 언어로 변환하는 시간을 기다릴 필요가 없다. 또한 N번째 줄에 문법적 오류가 있더라도 그 이전 줄들은 올바르게 수행된다. 하지만 컴파일 언어보다 처리 속도가 느리다는 단점이 있다. 대표적인 인터프리터 언어로는 파이썬이 있다.
# ![nn](인터프리터.png)
# 고급 언어가 인터프리터 방식으로 저급 언어로 변환되는 과정
#
#
# 　여기서 주의해야 할 점은, 컴파일 언어와 인터프리터 언어는 양분되는 개념이 아니라는 것이다. C와 C++처럼 명확히 구분되는 언어도 있지만,  현대의 많은 프로그래밍 언어는 컴파일 언어와 인터프리터 언어 사이의 경계가 불분명하다. 따라서, 하나의 프로그래밍 언어가 반드시 이 두 가지 중 하나만을 따르는 것이 아니라는 점에 유념하자. 즉, 고급 언어가 저급 언어로 변환되는 대표적인 방법에는 컴파일 방식과 인터프리트 방식이 있다고 이해하는 것이 바람직하다.
#
# https://maloveforme.tistory.com/148
# https://imasoftwareengineer.tistory.com/43

# %% [markdown]
# # EDA란?
#
# **Exploratory Data Analysis, 탐색적 데이터 분석**
#
# 수집한 데이터가 들어왔을 때 이를 다양한 각도에서 관찰하고 만져가며 데이터를 이해하는 과정을 뜻합니다.
#
# 단순하게는 데이터 각각의 열과 행이 무슨의미인지 확인해보고 <Br>내가 다뤄야할 관심사(변수들)를 테이블로 요약, 그래프화 하는 것부터,<br>
# 좀더 많이 들어가면 변수들간의 관계확인, 분포확인, 통계적 가설 검정을 통해 데이터를 직관적으로 바라보는 과정입니다.
#
# 이를 통해
#  * 데이터에 문제가 없는지 확인하고
#  * 데이터의 전체적인 구성을 이해하고
#  * 내가 현 데이터로 앞으로 어떤 분석을 할것인지 생각해보고
#  * 목적변수, 설명변수를 확인하여 앞으로의 분석 모형을 구체화 시킬 수 있습니다.

# %% [markdown]
# # Jupyter? jupyter notebook? colab?

# %% [markdown]
# ![img](https://upload.wikimedia.org/wikipedia/commons/thumb/3/38/Jupyter_logo.svg/250px-Jupyter_logo.svg.png)
#
#
#  프로젝트 주피터(영어: Project Jupyter, Listeni/ˈdʒuːpɪtər/)는 "오픈 소스 소프트웨어, 개방형 표준, 그리고 여러 개의 프로그래밍 언어에 걸쳐 인터랙티브 컴퓨팅을 위한 서비스 개발"을 위해 설립된 비영리 단체이다.
#
#  2014년에 페르난도 페레즈에 의해 IPython으로부터 파생된 프로젝트 주피터는 여러 개의 언어를 통한 실행 환경을 지원한다.
#
#  프로젝트 주피터의 이름은 주피터가 지원하는 세 개의 핵심 언어인 Julia, 파이썬 그리고 R에서 유래했으며, 목성의 위성의 발견이 기록된 갈릴레오 갈릴레이의 공책에 대한 존경의 의미도 갖는다.
#
#  프로젝트 주피터는 인터랙티브 컴퓨팅 제품인 주피터 노트북, 주피터허브, 그리고 주피터 노트북의 차세대 버전인 주피터랩을 개발하고 지원해왔다.
# https://ko.wikipedia.org/wiki/%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8_%EC%A3%BC%ED%94%BC%ED%84%B0

# %% [markdown]
# Jupyter Notebook은 오픈소스 웹 어플리케이션으로, 코드 작성, 시각화 및 문서 작성이 가능한 대화형 환경을 제공하는 도구입니다.
#
# 주피터 노트북에서는 코드 셀과 마크다운 셀로 구성되어 있습니다. 코드 셀에서는 파이썬 코드를 작성하고 실행할 수 있으며, 마크다운 셀에서는 문서를 작성하고, 수식을 표현하거나, 이미지를 삽입할 수 있습니다. 이러한 코드와 문서를 함께 작성할 수 있어 데이터 분석, 머신러닝 등의 프로젝트에서 매우 유용하게 사용됩니다.
#
# 또한, 주피터 노트북에서는 파이썬 코드를 한 줄씩 실행하면서 결과를 확인할 수 있어 디버깅과 테스트를 편리하게 수행할 수 있습니다. 코드를 실행하면 결과가 즉시 아래에 표시되며, 시각화된 그래프나 테이블 등을 바로 확인할 수 있습니다.
#
# Google Colab은 구글에서 제공하는 클라우드 기반 Jupyter Notebook 환경입니다.
# https://wikidocs.net/195613

# %% [markdown]
# # 0. Jupyter notebook 과 친해지기

# %% [markdown]
# Basic python coding

# %% [markdown]
# 1. 데이터 출력하기 (print)

# %%
print("Hello world")
# Out:
# Hello world

# %%
h = "Hello world"
h
# Out:
# 'Hello world'

# %%
print(h)
# Out:
# Hello world

# %% [markdown]
# 1.1. print 다루기

# %%
print("Hi, world")
print("Hi, Hello")
# Out:
# Hi, world
# Hi, Hello

# %% [markdown]
# python의 print는 기본적으로 문자의 마지막에 "\n" 을 포함하고 있습니다.
#
# end=" " 를 이용해서 이를 수정할 수 있습니다

# %%
print("Hi, world",end=" ")
print("Hi, Hello")
print("가나다라",end=", ")
print("마바사")
print("This space is",end="\t")
print("tab")
# Out:
# Hi, world Hi, Hello
# 가나다라, 마바사
# This space is	tab

# %% [markdown]
# 2. 조건문과 반복문

# %% [markdown]
# python은 tab 혹은 명령어 앞의 space를 이용헤서 명령어의 순서(?), 종속(?)을 구분합니다.

# %%
i = 3

if i > 10:
    print("over 10")
elif i > 5:
    print("under 10 and over 5")
else:
    print("under 5")
# Out:
# under 5

# %%
for i in h:
    print(i)
for i in h: print(i,end="")
# Out:
# H
# e
# l
# l
# o
#
# w
# o
# r
# l
# d
# Hello world

# %% [markdown]
# 3. list 자료형 다루기

# %% [markdown]
# 파이썬의 여러 자료형 중에 가장 많이 쓰게될 자료형

# %%
li = []
li
# Out:
# []

# %%
li.append("A")

# %%
li
# Out:
# ['A']

# %%
li.append("T")
li.append("G")
li.append("C")
li.append("C")
li.append("T")

# %%
li
# Out:
# ['A', 'T', 'G', 'C', 'C', 'T']

# %%
li[0]
# Out:
# 'A'

# %%
li[-1:]
# Out:
# ['T']

# %%
li[1:-1]
# Out:
# ['T', 'G', 'C', 'C']

# %%
for i in li:
    print(i)
# Out:
# A
# T
# G
# C
# C
# T

# %%
for i in li:
    if(i == "T"):
        print("U")
    else:
        print(i)
# Out:
# A
# U
# G
# C
# C
# U

# %%
for i in li:
    if(i == "T"):
        print("U")
        continue
    print(i)
# Out:
# A
# U
# G
# C
# C
# U

# %%
li
# Out:
# ['A', 'T', 'G', 'C', 'C', 'T']

# %%
temp = li

# %%
temp
# Out:
# ['A', 'T', 'G', 'C', 'C', 'T']

# %%
temp[1] = "U"
temp[-1] = "U"

# %%
temp
# Out:
# ['A', 'U', 'G', 'C', 'C', 'U']

# %% [markdown]
# 그렇다면 li 의 값은 변했을까? 변하지 않았을까??

# %%
li
# Out:
# ['A', 'U', 'G', 'C', 'C', 'U']

# %% [markdown]
# 위와 같은 경우 아래처럼 한가지 데이터를 가르키는 변수가 2개가 된 것이 되므로 주의해야한다.
# ![img](https://img1.daumcdn.net/thumb/R1280x0/?scode=mtistory2&fname=https%3A%2F%2Fblog.kakaocdn.net%2Fdn%2FZjMHE%2Fbtq1ztu7Pzn%2FkouoF7ALRHcULhBSn1Ml8k%2Fimg.png)

# %% [markdown]
# 위와 같은 경우를 회피하기 위해

# %%
li= ['A', 'T', 'G', 'C', 'C', 'T']

# %%
# 새롭게 리스트를 생성하던가
rn = []
for i in li:
    if(i == "T"):
        rn.append("U")
        continue
    rn.append(i)
rn
# Out:
# ['A', 'U', 'G', 'C', 'C', 'U']

# %%
li
# Out:
# ['A', 'T', 'G', 'C', 'C', 'T']

# %%
# deepcopy를 이용할 수 있다. 
import copy
temp_deepcopy = copy.deepcopy(li)

# %%
temp_deepcopy
# Out:
# ['A', 'T', 'G', 'C', 'C', 'T']

# %%
temp_deepcopy[1] = "U"
temp_deepcopy[-1] = "U"

# %%
temp_deepcopy
# Out:
# ['A', 'U', 'G', 'C', 'C', 'U']

# %%
li
# Out:
# ['A', 'T', 'G', 'T']

# %%
# 그외 각종 리스트 연산들
# 추가하는 방법
li  = li + ["A","A","A"]
print("Using '+' to add poly A to right end of li", end=" : ")
print(li)

li.extend(["T","T","T"])
print("Using '+' to add poly T to right end of li", end=" : ")
print(li)

li.insert(3,"T")
print("Using 'insert' to add T to index 3 in li", end=" : ")
print(li)

# 제거하는 방법
del li[3]
print("Using 'del' to remove T at index 3 in li", end=" : ")
print(li)

li.remove("A")
print("Using 'remove' to remove A first matched in target li(searching left to right / index ascending order)", end=" : \n")
print(li)
# Out:
# Using '+' to add poly A to right end of li : ['A', 'T', 'G', 'C', 'C', 'T', 'A', 'A', 'A']
# Using '+' to add poly T to right end of li : ['A', 'T', 'G', 'C', 'C', 'T', 'A', 'A', 'A', 'T', 'T', 'T']
# Using 'insert' to add T to index 3 in li : ['A', 'T', 'G', 'T', 'C', 'C', 'T', 'A', 'A', 'A', 'T', 'T', 'T']
# Using 'del' to remove T at index 3 in li : ['A', 'T', 'G', 'C', 'C', 'T', 'A', 'A', 'A', 'T', 'T', 'T']
# Using 'remove' to remove A first matched in target li(searching left to right / index ascending order) :
# ['T', 'G', 'C', 'C', 'T', 'A', 'A', 'A', 'T', 'T', 'T']

# %% [markdown]
# 실습 문제 :
#
# **주어진 리스트 li = ['A', 'T', 'G', 'C', 'C', 'T'] 에서 'C'를 지우는 알고리즘을 구현하여라**
#
# 단, 해당 값의 인덱스를 알 수 없다고 가정한다. -> 인덱스로 접근하여 삭제하지 말라

# %%
li = ['A', 'T', 'G', 'C', 'C', 'T']

# %%
temp = []
for i in li:
    if i == "C": continue
    temp.append(i)
li = temp
print(li)
# Out:
# ['A', 'T', 'G', 'T']

# %%
while True:
    try: li.remove("C")
    except: break
print(li)
# Out:
# ['A', 'T', 'G', 'T']

# %%
li = [i for i in li if i != "C"]
print(li)
# Out:
# ['A', 'T', 'G', 'T']

# %% [markdown]
# # 1. Pandas로 데이터 다루기

# %% [markdown]
# ![nn](pandas호환.png)
# https://pandas.pydata.org/docs/user_guide/io.html

# %% [markdown]
# # 우리가 불러올 데이터들
#
# **엑셀**
# ![nn](엑셀예시.png)
#
# **DEresults**
# ![nn](DEresults예시.png)

# %%
import pandas as pd

tsv_de_results = pd.read_csv("genes.counts.matrix.Blackblight_vs_Fireblight.edgeR.DE_results",sep="\t")
excel_gene2go_page1 = pd.read_excel("Pyrus_pyrifolia_v1.0_genes2Go.xlsx",skiprows=[0,1],sheet_name="Page 1")
excel_gene2go_page2 = pd.read_excel("Pyrus_pyrifolia_v1.0_genes2Go.xlsx",skiprows=[0,1],sheet_name="Page 2")

# %%
tsv_de_results
# Out:
#                      sampleA     sampleB     logFC    logCPM        PValue  \
# nbis-gene-37235  Blackblight  Fireblight -2.374873  5.366200  1.345069e-11
# nbis-gene-18755  Blackblight  Fireblight -6.050585  7.204897  3.354682e-11
# nbis-gene-25027  Blackblight  Fireblight -4.398183 -1.394791  1.021102e-10
# nbis-gene-4356   Blackblight  Fireblight -1.930094  6.391506  1.045660e-10
# nbis-gene-21473  Blackblight  Fireblight -2.458743  5.662868  1.631979e-10
# ...                      ...         ...       ...       ...           ...
# nbis-gene-36307  Blackblight  Fireblight -0.000677  5.335978  1.000000e+00
# nbis-gene-7179   Blackblight  Fireblight -0.000504  3.447191  1.000000e+00
# nbis-gene-17901  Blackblight  Fireblight -0.000268 -0.529541  1.000000e+00
# nbis-gene-10561  Blackblight  Fireblight -0.000149 -0.805470  1.000000e+00
# nbis-gene-17673  Blackblight  Fireblight -0.000010  0.169800  1.000000e+00
#
#                           FDR
# nbis-gene-37235  4.063184e-07
# nbis-gene-18755  5.066912e-07
# nbis-gene-25027  7.896827e-07
# nbis-gene-4356   7.896827e-07
# nbis-gene-21473  9.859762e-07
# ...                       ...
# nbis-gene-36307  1.000000e+00
# nbis-gene-7179   1.000000e+00
# nbis-gene-17901  1.000000e+00
# nbis-gene-10561  1.000000e+00
# nbis-gene-17673  1.000000e+00
#
# [30208 rows x 6 columns]

# %%
excel_gene2go_page1
# Out:
#                    Query       Match  \
# 0      Ppy00g0002.1_v1.0  GO:0005515
# 1      Ppy00g0005.1_v1.0  GO:0004672
# 2      Ppy00g0005.1_v1.0  GO:0005509
# 3      Ppy00g0005.1_v1.0  GO:0005524
# 4      Ppy00g0005.1_v1.0  GO:0006468
# ...                  ...         ...
# 29995  Ppy09g0836.1_v1.0  GO:0004930
# 29996  Ppy09g0836.1_v1.0  GO:0007186
# 29997  Ppy09g0836.1_v1.0  GO:0016021
# 29998  Ppy09g0838.1_v1.0  GO:0003735
# 29999  Ppy09g0838.1_v1.0  GO:0005840
#
#                                              Description
# 0                     Molecular Function:protein binding
# 1             Molecular Function:protein kinase activity
# 2                 Molecular Function:calcium ion binding
# 3                         Molecular Function:ATP binding
# 4             Biological Process:protein phosphorylation
# ...                                                  ...
# 29995  Molecular Function:G protein-coupled receptor ...
# 29996  Biological Process:G protein-coupled receptor ...
# 29997  Cellular Component:integral component of membrane
# 29998  Molecular Function:structural constituent of r...
# 29999                        Cellular Component:ribosome
#
# [30000 rows x 3 columns]

# %%
excel_gene2go_page2
# Out:
#                    Query       Match  \
# 0      Ppy09g0838.1_v1.0  GO:0006412
# 1      Ppy09g0838.1_v1.0  GO:0019843
# 2      Ppy09g0839.1_v1.0  GO:0015297
# 3      Ppy09g0839.1_v1.0  GO:0016020
# 4      Ppy09g0839.1_v1.0  GO:0042910
# ...                  ...         ...
# 29985  Ppy17g2633.1_v1.0  GO:0004725
# 29986  Ppy17g2633.1_v1.0  GO:0006470
# 29987  Ppy17g2633.1_v1.0  GO:0016311
# 29988  Ppy17g2633.1_v1.0  GO:0016791
# 29989  Ppy17g2635.1_v1.0  GO:0051321
#
#                                              Description
# 0                         Biological Process:translation
# 1                        Molecular Function:rRNA binding
# 2                 Molecular Function:antiporter activity
# 3                            Cellular Component:membrane
# 4      Molecular Function:xenobiotic transmembrane tr...
# ...                                                  ...
# 29985  Molecular Function:protein tyrosine phosphatas...
# 29986       Biological Process:protein dephosphorylation
# 29987               Biological Process:dephosphorylation
# 29988            Molecular Function:phosphatase activity
# 29989              Biological Process:meiotic cell cycle
#
# [29990 rows x 3 columns]

# %% [markdown]
# # 먼저 DE results 다루기
#
# # Dataframe의 구성요소
#
# ![img](https://img1.daumcdn.net/thumb/R1280x0/?scode=mtistory2&fname=https%3A%2F%2Fblog.kakaocdn.net%2Fdn%2F33VT3%2Fbtq3DsGFPDT%2FrohQwEp2Z72zkVHvX9SRN1%2Fimg.png)

# %%
tsv_de_results
# Out:
#                      sampleA     sampleB     logFC    logCPM        PValue  \
# nbis-gene-37235  Blackblight  Fireblight -2.374873  5.366200  1.345069e-11
# nbis-gene-18755  Blackblight  Fireblight -6.050585  7.204897  3.354682e-11
# nbis-gene-25027  Blackblight  Fireblight -4.398183 -1.394791  1.021102e-10
# nbis-gene-4356   Blackblight  Fireblight -1.930094  6.391506  1.045660e-10
# nbis-gene-21473  Blackblight  Fireblight -2.458743  5.662868  1.631979e-10
# ...                      ...         ...       ...       ...           ...
# nbis-gene-36307  Blackblight  Fireblight -0.000677  5.335978  1.000000e+00
# nbis-gene-7179   Blackblight  Fireblight -0.000504  3.447191  1.000000e+00
# nbis-gene-17901  Blackblight  Fireblight -0.000268 -0.529541  1.000000e+00
# nbis-gene-10561  Blackblight  Fireblight -0.000149 -0.805470  1.000000e+00
# nbis-gene-17673  Blackblight  Fireblight -0.000010  0.169800  1.000000e+00
#
#                           FDR
# nbis-gene-37235  4.063184e-07
# nbis-gene-18755  5.066912e-07
# nbis-gene-25027  7.896827e-07
# nbis-gene-4356   7.896827e-07
# nbis-gene-21473  9.859762e-07
# ...                       ...
# nbis-gene-36307  1.000000e+00
# nbis-gene-7179   1.000000e+00
# nbis-gene-17901  1.000000e+00
# nbis-gene-10561  1.000000e+00
# nbis-gene-17673  1.000000e+00
#
# [30208 rows x 6 columns]

# %%
tsv_de_results.index
# Out:
# Index(['nbis-gene-37235', 'nbis-gene-18755', 'nbis-gene-25027',
#        'nbis-gene-4356', 'nbis-gene-21473', 'nbis-gene-36623',
#        'nbis-gene-18599', 'nbis-gene-40111', 'nbis-gene-37989',
#        'nbis-gene-22768',
#        ...
#        'nbis-gene-34520', 'nbis-gene-40117', 'nbis-gene-39264',
#        'nbis-gene-3697', 'nbis-gene-29732', 'nbis-gene-36307',
#        'nbis-gene-7179', 'nbis-gene-17901', 'nbis-gene-10561',
#        'nbis-gene-17673'],
#       dtype='object', length=30208)

# %%
# Pandas 
tsv_de_results.PValue
# Out:
# nbis-gene-37235    1.345069e-11
# nbis-gene-18755    3.354682e-11
# nbis-gene-25027    1.021102e-10
# nbis-gene-4356     1.045660e-10
# nbis-gene-21473    1.631979e-10
#                        ...
# nbis-gene-36307    1.000000e+00
# nbis-gene-7179     1.000000e+00
# nbis-gene-17901    1.000000e+00
# nbis-gene-10561    1.000000e+00
# nbis-gene-17673    1.000000e+00
# Name: PValue, Length: 30208, dtype: float64

# %%
tsv_de_results["PValue"]
# Out:
# nbis-gene-37235    1.345069e-11
# nbis-gene-18755    3.354682e-11
# nbis-gene-25027    1.021102e-10
# nbis-gene-4356     1.045660e-10
# nbis-gene-21473    1.631979e-10
#                        ...
# nbis-gene-36307    1.000000e+00
# nbis-gene-7179     1.000000e+00
# nbis-gene-17901    1.000000e+00
# nbis-gene-10561    1.000000e+00
# nbis-gene-17673    1.000000e+00
# Name: PValue, Length: 30208, dtype: float64

# %%
# Pandas data frame의 구성요소
print("Dataframe : ", end ="")
print(type(tsv_de_results))
print("Series : " ,end ="")
print(type(tsv_de_results.PValue))
# Out:
# Dataframe : <class 'pandas.core.frame.DataFrame'>
# Series : <class 'pandas.core.series.Series'>

# %% [markdown]
# # 보이는 것처럼 DataFrame과 Serise는 index를 가지고 있습니다.
#
# -> 인덱스로 접근하는 것이 가능하다.

# %%
tsv_de_results.loc["nbis-gene-22768"]
# Out:
# sampleA    Blackblight
# sampleB     Fireblight
# logFC        -3.427766
# logCPM        6.419731
# PValue             0.0
# FDR           0.000005
# Name: nbis-gene-22768, dtype: object

# %%
# 옆으로 가져온 경우에도 시리즈로 가져옵니다.!!
print("Series : " ,end ="")
print(type(tsv_de_results.loc["nbis-gene-22768"]))
# Out:
# Series : <class 'pandas.core.series.Series'>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# sns style
sns.set_style('white')

# plot size
plt.rcParams["figure.figsize"] = [10, 10]
plt.rcParams["figure.dpi"] = 600

# %%
def DE_volcano(DE_results_df,FDR_float,FC_float, visualization=True):
    #Up regulated
    fc = DE_results_df["logFC"] > FC_float 
    fdr = DE_results_df["FDR"] < FDR_float
    fc_fdr = fc * fdr
    fc_fdr = fc_fdr.astype(str)
    fc_fdr = fc_fdr.replace("True", 1)
    fc_fdr = fc_fdr.replace("False", 0)

    #Down regulated
    d_fc = DE_results_df["logFC"] < -(FC_float) 

    d_fc_fdr = d_fc * fdr
    d_fc_fdr = d_fc_fdr.astype(str)
    d_fc_fdr = d_fc_fdr.replace("True", -1)
    d_fc_fdr = d_fc_fdr.replace("False", 0)

    Threshold = fc_fdr + d_fc_fdr

    Threshold = Threshold.replace(1, "UP")
    Threshold = Threshold.replace(0, "_")
    Threshold = Threshold.replace(-1, "DOWN")
    
    DE_for_Volca = DE_results_df
    DE_for_Volca["Threshold"] = Threshold 
    DE_for_Volca["-logFDR"] = -np.log10(DE_for_Volca["FDR"])
    
    if visualization:
        sns.set_style('white', rc=None)
        colors = {"UP": "Red", "_": "black", "DOWN": "Blue"}
        sns.scatterplot(data=DE_for_Volca, x='logFC', y='-logFDR', hue="Threshold", edgecolor='none',alpha=0.7, palette = colors)
        #plt.xscale('log') # log scaling
        plt.xlabel("logFC")
        plt.ylabel("-log FDR")
        plt.title('Volcano plot for DEGs', fontsize=20)
        #plt.grid(True, which='major', linestyle='--', linewidth=0.5)
        plt.legend(bbox_to_anchor = (1,1))
        plt.show()
    
    return DE_for_Volca

# %%
DE_volcano(tsv_de_results,0.05,1)
# Out:
#                      sampleA     sampleB     logFC    logCPM        PValue  \
# nbis-gene-37235  Blackblight  Fireblight -2.374873  5.366200  1.345069e-11
# nbis-gene-18755  Blackblight  Fireblight -6.050585  7.204897  3.354682e-11
# nbis-gene-25027  Blackblight  Fireblight -4.398183 -1.394791  1.021102e-10
# nbis-gene-4356   Blackblight  Fireblight -1.930094  6.391506  1.045660e-10
# nbis-gene-21473  Blackblight  Fireblight -2.458743  5.662868  1.631979e-10
# ...                      ...         ...       ...       ...           ...
# nbis-gene-36307  Blackblight  Fireblight -0.000677  5.335978  1.000000e+00
# nbis-gene-7179   Blackblight  Fireblight -0.000504  3.447191  1.000000e+00
# nbis-gene-17901  Blackblight  Fireblight -0.000268 -0.529541  1.000000e+00
# nbis-gene-10561  Blackblight  Fireblight -0.000149 -0.805470  1.000000e+00
# nbis-gene-17673  Blackblight  Fireblight -0.000010  0.169800  1.000000e+00
#
#                           FDR Threshold   -logFDR
# nbis-gene-37235  4.063184e-07      DOWN  6.391133
# nbis-gene-18755  5.066912e-07      DOWN  6.295257
# nbis-gene-25027  7.896827e-07      DOWN  6.102547
# nbis-gene-4356   7.896827e-07      DOWN  6.102547
# nbis-gene-21473  9.859762e-07      DOWN  6.006134
# ...                       ...       ...       ...
# nbis-gene-36307  1.000000e+00         _ -0.000000
# nbis-gene-7179   1.000000e+00         _ -0.000000
# nbis-gene-17901  1.000000e+00         _ -0.000000
# nbis-gene-10561  1.000000e+00         _ -0.000000
# nbis-gene-17673  1.000000e+00         _ -0.000000
#
# [30208 rows x 8 columns]

# %%
DE_modified = DE_volcano(tsv_de_results,0.05,1,False)

# %%
DE_modified["Threshold"] == "UP"
# Out:
# nbis-gene-37235    False
# nbis-gene-18755    False
# nbis-gene-25027    False
# nbis-gene-4356     False
# nbis-gene-21473    False
#                    ...
# nbis-gene-36307    False
# nbis-gene-7179     False
# nbis-gene-17901    False
# nbis-gene-10561    False
# nbis-gene-17673    False
# Name: Threshold, Length: 30208, dtype: bool

# %%
DE_modified[DE_modified["Threshold"] == "UP"]
# Out:
#                      sampleA     sampleB     logFC    logCPM        PValue  \
# nbis-gene-18765  Blackblight  Fireblight  1.681268  4.593924  5.705510e-09
# nbis-gene-36157  Blackblight  Fireblight  1.014253  4.071964  2.369963e-08
# nbis-gene-20783  Blackblight  Fireblight  3.186490 -0.296575  1.246456e-07
# nbis-gene-25409  Blackblight  Fireblight  1.241649  5.572411  1.910320e-07
# nbis-gene-14298  Blackblight  Fireblight  1.236852 -0.040249  2.546899e-07
# ...                      ...         ...       ...       ...           ...
# nbis-gene-36739  Blackblight  Fireblight  4.074009 -0.047082  5.396512e-03
# nbis-gene-27281  Blackblight  Fireblight  1.765830 -0.227172  5.710770e-03
# nbis-gene-3606   Blackblight  Fireblight  1.097191  3.021246  5.717511e-03
# nbis-gene-7148   Blackblight  Fireblight  4.029128 -0.506978  5.871651e-03
# nbis-gene-7284   Blackblight  Fireblight  1.006939 -0.236238  5.947491e-03
#
#                       FDR Threshold   -logFDR
# nbis-gene-18765  0.000008        UP  5.106006
# nbis-gene-36157  0.000015        UP  4.810342
# nbis-gene-20783  0.000039        UP  4.410329
# nbis-gene-25409  0.000049        UP  4.307326
# nbis-gene-14298  0.000062        UP  4.210776
# ...                   ...       ...       ...
# nbis-gene-36739  0.046804        UP  1.329718
# nbis-gene-27281  0.048445        UP  1.314755
# nbis-gene-3606   0.048474        UP  1.314487
# nbis-gene-7148   0.049421        UP  1.306091
# nbis-gene-7284   0.049782        UP  1.302931
#
# [178 rows x 8 columns]

# %%
DE_modified[DE_modified["Threshold"] == "DOWN"]
# Out:
#                      sampleA     sampleB     logFC    logCPM        PValue  \
# nbis-gene-37235  Blackblight  Fireblight -2.374873  5.366200  1.345069e-11
# nbis-gene-18755  Blackblight  Fireblight -6.050585  7.204897  3.354682e-11
# nbis-gene-25027  Blackblight  Fireblight -4.398183 -1.394791  1.021102e-10
# nbis-gene-4356   Blackblight  Fireblight -1.930094  6.391506  1.045660e-10
# nbis-gene-21473  Blackblight  Fireblight -2.458743  5.662868  1.631979e-10
# ...                      ...         ...       ...       ...           ...
# nbis-gene-21677  Blackblight  Fireblight -1.125321  4.153602  5.880155e-03
# nbis-gene-25798  Blackblight  Fireblight -1.702472  0.645199  5.887512e-03
# nbis-gene-17991  Blackblight  Fireblight -1.952302  2.458401  5.919579e-03
# nbis-gene-39955  Blackblight  Fireblight -1.337488  0.443098  5.919976e-03
# nbis-gene-44688  Blackblight  Fireblight -2.050904  2.663010  5.945886e-03
#
#                           FDR Threshold   -logFDR
# nbis-gene-37235  4.063184e-07      DOWN  6.391133
# nbis-gene-18755  5.066912e-07      DOWN  6.295257
# nbis-gene-25027  7.896827e-07      DOWN  6.102547
# nbis-gene-4356   7.896827e-07      DOWN  6.102547
# nbis-gene-21473  9.859762e-07      DOWN  6.006134
# ...                       ...       ...       ...
# nbis-gene-21677  4.946469e-02      DOWN  1.305705
# nbis-gene-25798  4.946478e-02      DOWN  1.305704
# nbis-gene-17991  4.964759e-02      DOWN  1.304102
# nbis-gene-39955  4.964759e-02      DOWN  1.304102
# nbis-gene-44688  4.978160e-02      DOWN  1.302931
#
# [1475 rows x 8 columns]

# %% [markdown]
# # Excel 데이터를 다뤄보자

# %%
excel_gene2go_page1
# Out:
#                    Query       Match  \
# 0      Ppy00g0002.1_v1.0  GO:0005515
# 1      Ppy00g0005.1_v1.0  GO:0004672
# 2      Ppy00g0005.1_v1.0  GO:0005509
# 3      Ppy00g0005.1_v1.0  GO:0005524
# 4      Ppy00g0005.1_v1.0  GO:0006468
# ...                  ...         ...
# 29995  Ppy09g0836.1_v1.0  GO:0004930
# 29996  Ppy09g0836.1_v1.0  GO:0007186
# 29997  Ppy09g0836.1_v1.0  GO:0016021
# 29998  Ppy09g0838.1_v1.0  GO:0003735
# 29999  Ppy09g0838.1_v1.0  GO:0005840
#
#                                              Description
# 0                     Molecular Function:protein binding
# 1             Molecular Function:protein kinase activity
# 2                 Molecular Function:calcium ion binding
# 3                         Molecular Function:ATP binding
# 4             Biological Process:protein phosphorylation
# ...                                                  ...
# 29995  Molecular Function:G protein-coupled receptor ...
# 29996  Biological Process:G protein-coupled receptor ...
# 29997  Cellular Component:integral component of membrane
# 29998  Molecular Function:structural constituent of r...
# 29999                        Cellular Component:ribosome
#
# [30000 rows x 3 columns]

# %%
excel_gene2go_page1["Description"]
# Out:
# 0                       Molecular Function:protein binding
# 1               Molecular Function:protein kinase activity
# 2                   Molecular Function:calcium ion binding
# 3                           Molecular Function:ATP binding
# 4               Biological Process:protein phosphorylation
#                                ...
# 29995    Molecular Function:G protein-coupled receptor ...
# 29996    Biological Process:G protein-coupled receptor ...
# 29997    Cellular Component:integral component of membrane
# 29998    Molecular Function:structural constituent of r...
# 29999                          Cellular Component:ribosome
# Name: Description, Length: 30000, dtype: object

# %%
go =[]
term = []
for i in excel_gene2go_page1["Description"]:
    go.append(i.split(":")[0])
    term.append("".join(i.split(":")[1:]))

# %%
excel_gene2go_page1["GO"] = go
excel_gene2go_page1["Term"] = term

# %%
excel_gene2go_page1
# Out:
#                    Query       Match  \
# 0      Ppy00g0002.1_v1.0  GO:0005515
# 1      Ppy00g0005.1_v1.0  GO:0004672
# 2      Ppy00g0005.1_v1.0  GO:0005509
# 3      Ppy00g0005.1_v1.0  GO:0005524
# 4      Ppy00g0005.1_v1.0  GO:0006468
# ...                  ...         ...
# 29995  Ppy09g0836.1_v1.0  GO:0004930
# 29996  Ppy09g0836.1_v1.0  GO:0007186
# 29997  Ppy09g0836.1_v1.0  GO:0016021
# 29998  Ppy09g0838.1_v1.0  GO:0003735
# 29999  Ppy09g0838.1_v1.0  GO:0005840
#
#                                              Description                  GO  \
# 0                     Molecular Function:protein binding  Molecular Function
# 1             Molecular Function:protein kinase activity  Molecular Function
# 2                 Molecular Function:calcium ion binding  Molecular Function
# 3                         Molecular Function:ATP binding  Molecular Function
# 4             Biological Process:protein phosphorylation  Biological Process
# ...                                                  ...                 ...
# 29995  Molecular Function:G protein-coupled receptor ...  Molecular Function
# 29996  Biological Process:G protein-coupled receptor ...  Biological Process
# 29997  Cellular Component:integral component of membrane  Cellular Component
# 29998  Molecular Function:structural constituent of r...  Molecular Function
# 29999                        Cellular Component:ribosome  Cellular Component
#
#                                                Term
# 0                                   protein binding
# 1                           protein kinase activity
# 2                               calcium ion binding
# 3                                       ATP binding
# 4                           protein phosphorylation
# ...                                             ...
# 29995           G protein-coupled receptor activity
# 29996  G protein-coupled receptor signaling pathway
# 29997                integral component of membrane
# 29998            structural constituent of ribosome
# 29999                                      ribosome
#
# [30000 rows x 5 columns]

# %%
excel_gene2go_page1[["Query","Match","GO","Term"]]
# Out:
#                    Query       Match                  GO  \
# 0      Ppy00g0002.1_v1.0  GO:0005515  Molecular Function
# 1      Ppy00g0005.1_v1.0  GO:0004672  Molecular Function
# 2      Ppy00g0005.1_v1.0  GO:0005509  Molecular Function
# 3      Ppy00g0005.1_v1.0  GO:0005524  Molecular Function
# 4      Ppy00g0005.1_v1.0  GO:0006468  Biological Process
# ...                  ...         ...                 ...
# 29995  Ppy09g0836.1_v1.0  GO:0004930  Molecular Function
# 29996  Ppy09g0836.1_v1.0  GO:0007186  Biological Process
# 29997  Ppy09g0836.1_v1.0  GO:0016021  Cellular Component
# 29998  Ppy09g0838.1_v1.0  GO:0003735  Molecular Function
# 29999  Ppy09g0838.1_v1.0  GO:0005840  Cellular Component
#
#                                                Term
# 0                                   protein binding
# 1                           protein kinase activity
# 2                               calcium ion binding
# 3                                       ATP binding
# 4                           protein phosphorylation
# ...                                             ...
# 29995           G protein-coupled receptor activity
# 29996  G protein-coupled receptor signaling pathway
# 29997                integral component of membrane
# 29998            structural constituent of ribosome
# 29999                                      ribosome
#
# [30000 rows x 4 columns]

# %%
go =[]
term = []
for i in excel_gene2go_page2["Description"]:
    go.append(i.split(":")[0])
    term.append("".join(i.split(":")[1:]))
    
excel_gene2go_page2["GO"] = go
excel_gene2go_page2["Term"] = term

# %%
excel_gene2go_page2[["Query","Match","GO","Term"]]
# Out:
#                    Query       Match                  GO  \
# 0      Ppy09g0838.1_v1.0  GO:0006412  Biological Process
# 1      Ppy09g0838.1_v1.0  GO:0019843  Molecular Function
# 2      Ppy09g0839.1_v1.0  GO:0015297  Molecular Function
# 3      Ppy09g0839.1_v1.0  GO:0016020  Cellular Component
# 4      Ppy09g0839.1_v1.0  GO:0042910  Molecular Function
# ...                  ...         ...                 ...
# 29985  Ppy17g2633.1_v1.0  GO:0004725  Molecular Function
# 29986  Ppy17g2633.1_v1.0  GO:0006470  Biological Process
# 29987  Ppy17g2633.1_v1.0  GO:0016311  Biological Process
# 29988  Ppy17g2633.1_v1.0  GO:0016791  Molecular Function
# 29989  Ppy17g2635.1_v1.0  GO:0051321  Biological Process
#
#                                                 Term
# 0                                        translation
# 1                                       rRNA binding
# 2                                antiporter activity
# 3                                           membrane
# 4      xenobiotic transmembrane transporter activity
# ...                                              ...
# 29985          protein tyrosine phosphatase activity
# 29986                      protein dephosphorylation
# 29987                              dephosphorylation
# 29988                           phosphatase activity
# 29989                             meiotic cell cycle
#
# [29990 rows x 4 columns]

# %%
target1 = excel_gene2go_page1[["Query","Match","GO","Term"]]
target2 = excel_gene2go_page2[["Query","Match","GO","Term"]]

# %%
pd.concat([target1,target2])
# Out:
#                    Query       Match                  GO  \
# 0      Ppy00g0002.1_v1.0  GO:0005515  Molecular Function
# 1      Ppy00g0005.1_v1.0  GO:0004672  Molecular Function
# 2      Ppy00g0005.1_v1.0  GO:0005509  Molecular Function
# 3      Ppy00g0005.1_v1.0  GO:0005524  Molecular Function
# 4      Ppy00g0005.1_v1.0  GO:0006468  Biological Process
# ...                  ...         ...                 ...
# 29985  Ppy17g2633.1_v1.0  GO:0004725  Molecular Function
# 29986  Ppy17g2633.1_v1.0  GO:0006470  Biological Process
# 29987  Ppy17g2633.1_v1.0  GO:0016311  Biological Process
# 29988  Ppy17g2633.1_v1.0  GO:0016791  Molecular Function
# 29989  Ppy17g2635.1_v1.0  GO:0051321  Biological Process
#
#                                         Term
# 0                            protein binding
# 1                    protein kinase activity
# 2                        calcium ion binding
# 3                                ATP binding
# 4                    protein phosphorylation
# ...                                      ...
# 29985  protein tyrosine phosphatase activity
# 29986              protein dephosphorylation
# 29987                      dephosphorylation
# 29988                   phosphatase activity
# 29989                     meiotic cell cycle
#
# [59990 rows x 4 columns]

# %% [markdown]
# 뭔가 이상한 점이 있다 -> 인덱스가 유일하지 정렬도 안되고 중복되게 되었다.
# 인덱스를 재설정하여 수정가능하다.

# %%
excel_gene2go = pd.concat([target1,target2])

# %%
gene_id = [i.split("_v")[0] for i in excel_gene2go["Query"]]

# %%
gene_id
# Out:
# ['Ppy00g0002.1',
#  'Ppy00g0005.1',
#  'Ppy00g0005.1',
#  'Ppy00g0005.1',
#  'Ppy00g0005.1',
#  'Ppy00g0006.1',
#  'Ppy00g0006.1',
#  'Ppy00g0006.1',
#  'Ppy00g0008.1',
#  'Ppy00g0008.1',
#  'Ppy00g0008.1',
#  'Ppy00g0015.1',
#  'Ppy00g0015.1',
#  'Ppy00g0015.1',
#  'Ppy00g0016.1',
#  'Ppy00g0016.1',
#  'Ppy00g0016.1',
#  'Ppy00g0018.1',
#  'Ppy00g0018.1',
#  'Ppy00g0018.1',
#  'Ppy00g0018.1',
#  'Ppy00g0020.1',
#  'Ppy00g0021.1',
#  'Ppy00g0021.1',
#  'Ppy00g0021.1',
#  'Ppy00g0021.1',
#  'Ppy00g0024.1',
#  'Ppy00g0024.1',
#  'Ppy00g0025.1',
#  'Ppy00g0025.1',
#  'Ppy00g0025.1',
#  'Ppy00g0025.1',
#  'Ppy00g0026.1',
#  'Ppy00g0026.1',
#  'Ppy00g0027.1',
#  'Ppy00g0027.1',
#  'Ppy00g0029.1',
#  'Ppy00g0033.1',
#  'Ppy00g0033.1',
#  'Ppy00g0034.1',
#  'Ppy00g0035.1',
#  'Ppy00g0036.1',
#  'Ppy00g0036.1',
#  'Ppy00g0037.1',
#  'Ppy00g0037.1',
#  'Ppy00g0039.1',
#  'Ppy00g0040.1',
#  'Ppy00g0040.1',
#  'Ppy00g0040.1',
#  'Ppy00g0042.1',
#  'Ppy00g0042.1',
#  'Ppy00g0043.1',
#  'Ppy00g0043.1',
#  'Ppy00g0044.1',
#  'Ppy00g0044.1',
#  'Ppy00g0045.1',
#  'Ppy00g0045.1',
#  'Ppy00g0046.1',
#  'Ppy00g0046.1',
#  'Ppy00g0047.1',
#  'Ppy00g0047.1',
#  'Ppy00g0049.1',
#  'Ppy00g0050.1',
#  'Ppy00g0051.1',
#  'Ppy00g0051.1',
#  'Ppy00g0051.1',
#  'Ppy00g0053.1',
#  'Ppy00g0054.1',
#  'Ppy00g0060.1',
#  'Ppy00g0065.1',
#  'Ppy00g0075.1',
#  'Ppy00g0075.1',
#  'Ppy00g0076.1',
#  'Ppy00g0077.1',
#  'Ppy00g0083.1',
#  'Ppy00g0091.1',
#  'Ppy00g0092.1',
#  'Ppy00g0094.1',
#  'Ppy00g0094.1',
#  'Ppy00g0094.1',
#  'Ppy00g0094.1',
#  'Ppy00g0097.1',
#  'Ppy00g0097.1',
#  'Ppy00g0098.1',
#  'Ppy00g0106.1',
#  'Ppy00g0106.1',
#  'Ppy00g0111.1',
#  'Ppy00g0113.1',
#  'Ppy00g0115.1',
#  'Ppy00g0115.1',
#  'Ppy00g0115.1',
#  'Ppy00g0115.1',
#  'Ppy00g0120.1',
#  'Ppy00g0120.1',
#  'Ppy00g0123.1',
#  'Ppy00g0123.1',
#  'Ppy00g0123.1',
#  'Ppy00g0123.1',
#  'Ppy00g0125.1',
#  'Ppy00g0125.1',
#  'Ppy00g0125.1',
#  'Ppy00g0129.1',
#  'Ppy00g0130.1',
#  'Ppy00g0131.1',
#  'Ppy00g0131.1',
#  'Ppy00g0131.1',
#  'Ppy00g0133.1',
#  'Ppy00g0133.1',
#  'Ppy00g0134.1',
#  'Ppy00g0134.1',
#  'Ppy00g0134.1',
#  'Ppy00g0134.1',
#  'Ppy00g0135.1',
#  'Ppy00g0135.1',
#  'Ppy00g0135.1',
#  'Ppy00g0135.1',
#  'Ppy00g0135.1',
#  'Ppy00g0136.1',
#  'Ppy00g0137.1',
#  'Ppy00g0137.1',
#  'Ppy00g0137.1',
#  'Ppy00g0137.1',
#  'Ppy00g0137.1',
#  'Ppy00g0141.1',
#  'Ppy00g0143.1',
#  'Ppy00g0145.1',
#  'Ppy00g0145.1',
#  'Ppy00g0146.1',
#  'Ppy00g0148.1',
#  'Ppy00g0149.1',
#  'Ppy00g0150.1',
#  'Ppy00g0150.1',
#  'Ppy00g0150.1',
#  'Ppy00g0154.1',
#  'Ppy00g0154.1',
#  'Ppy00g0155.1',
#  'Ppy00g0157.1',
#  'Ppy00g0159.1',
#  'Ppy00g0159.1',
#  'Ppy00g0160.1',
#  'Ppy00g0160.1',
#  'Ppy00g0161.1',
#  'Ppy00g0161.1',
#  'Ppy00g0162.1',
#  'Ppy00g0162.1',
#  'Ppy00g0163.1',
#  'Ppy00g0165.1',
#  'Ppy00g0165.1',
#  'Ppy00g0165.1',
#  'Ppy00g0168.1',
#  'Ppy00g0168.1',
#  'Ppy00g0169.1',
#  'Ppy00g0169.1',
#  'Ppy00g0169.1',
#  'Ppy00g0170.1',
#  'Ppy00g0170.1',
#  'Ppy00g0172.1',
#  'Ppy00g0172.1',
#  'Ppy00g0173.1',
#  'Ppy00g0173.1',
#  'Ppy00g0173.1',
#  'Ppy00g0173.1',
#  'Ppy00g0177.1',
#  'Ppy00g0178.1',
#  'Ppy00g0179.1',
#  'Ppy00g0179.1',
#  'Ppy00g0180.1',
#  'Ppy00g0180.1',
#  'Ppy00g0180.1',
#  'Ppy00g0180.1',
#  'Ppy00g0180.1',
#  'Ppy00g0182.1',
#  'Ppy00g0182.1',
#  'Ppy00g0182.1',
#  'Ppy00g0182.1',
#  'Ppy00g0183.1',
#  'Ppy00g0184.1',
#  'Ppy00g0187.1',
#  'Ppy00g0188.1',
#  'Ppy00g0188.1',
#  'Ppy00g0188.1',
#  'Ppy00g0188.1',
#  'Ppy00g0189.1',
#  'Ppy00g0189.1',
#  'Ppy00g0190.1',
#  'Ppy00g0190.1',
#  'Ppy00g0194.1',
#  'Ppy00g0194.1',
#  'Ppy00g0195.1',
#  'Ppy00g0196.1',
#  'Ppy00g0196.1',
#  'Ppy00g0196.1',
#  'Ppy00g0196.1',
#  'Ppy00g0196.1',
#  'Ppy00g0197.1',
#  'Ppy00g0198.1',
#  'Ppy00g0199.1',
#  'Ppy00g0199.1',
#  'Ppy00g0199.1',
#  'Ppy00g0200.1',
#  'Ppy00g0204.1',
#  'Ppy00g0204.1',
#  'Ppy00g0205.1',
#  'Ppy00g0205.1',
#  'Ppy00g0208.1',
#  'Ppy00g0208.1',
#  'Ppy00g0208.1',
#  'Ppy00g0210.1',
#  'Ppy00g0210.1',
#  'Ppy00g0210.1',
#  'Ppy00g0211.1',
#  'Ppy00g0211.1',
#  'Ppy00g0211.1',
#  'Ppy00g0212.1',
#  'Ppy00g0212.1',
#  'Ppy00g0212.1',
#  'Ppy00g0212.1',
#  'Ppy00g0214.1',
#  'Ppy00g0214.1',
#  'Ppy00g0214.1',
#  'Ppy00g0215.1',
#  'Ppy00g0216.1',
#  'Ppy00g0216.1',
#  'Ppy00g0217.1',
#  'Ppy00g0217.1',
#  'Ppy00g0218.1',
#  'Ppy00g0218.1',
#  'Ppy00g0218.1',
#  'Ppy00g0221.1',
#  'Ppy00g0221.1',
#  'Ppy00g0221.1',
#  'Ppy00g0221.1',
#  'Ppy00g0221.1',
#  'Ppy00g0222.1',
#  'Ppy00g0225.1',
#  'Ppy00g0225.1',
#  'Ppy00g0228.1',
#  'Ppy00g0229.1',
#  'Ppy00g0229.1',
#  'Ppy00g0229.1',
#  'Ppy00g0229.1',
#  'Ppy00g0230.1',
#  'Ppy00g0230.1',
#  'Ppy00g0230.1',
#  'Ppy00g0231.1',
#  'Ppy00g0231.1',
#  'Ppy00g0231.1',
#  'Ppy00g0232.1',
#  'Ppy00g0232.1',
#  'Ppy00g0233.1',
#  'Ppy00g0233.1',
#  'Ppy00g0233.1',
#  'Ppy00g0233.1',
#  'Ppy00g0233.1',
#  'Ppy00g0237.1',
#  'Ppy00g0238.1',
#  'Ppy00g0238.1',
#  'Ppy00g0238.1',
#  'Ppy00g0238.1',
#  'Ppy00g0239.1',
#  'Ppy00g0239.1',
#  'Ppy00g0240.1',
#  'Ppy00g0240.1',
#  'Ppy00g0240.1',
#  'Ppy00g0241.1',
#  'Ppy00g0241.1',
#  'Ppy00g0242.1',
#  'Ppy00g0245.1',
#  'Ppy00g0245.1',
#  'Ppy00g0245.1',
#  'Ppy00g0246.1',
#  'Ppy00g0246.1',
#  'Ppy00g0246.1',
#  'Ppy00g0247.1',
#  'Ppy00g0248.1',
#  'Ppy00g0248.1',
#  'Ppy00g0248.1',
#  'Ppy00g0248.1',
#  'Ppy00g0248.1',
#  'Ppy00g0249.1',
#  'Ppy00g0250.1',
#  'Ppy00g0250.1',
#  'Ppy00g0250.1',
#  'Ppy00g0251.1',
#  'Ppy00g0251.1',
#  'Ppy00g0251.1',
#  'Ppy00g0254.1',
#  'Ppy00g0255.1',
#  'Ppy00g0255.1',
#  'Ppy00g0255.1',
#  'Ppy00g0255.1',
#  'Ppy00g0255.1',
#  'Ppy00g0255.1',
#  'Ppy00g0256.1',
#  'Ppy00g0256.1',
#  'Ppy00g0256.1',
#  'Ppy00g0256.1',
#  'Ppy00g0256.1',
#  'Ppy00g0257.1',
#  'Ppy00g0258.1',
#  'Ppy00g0259.1',
#  'Ppy00g0261.1',
#  'Ppy00g0261.1',
#  'Ppy00g0261.1',
#  'Ppy00g0261.1',
#  'Ppy00g0261.1',
#  'Ppy00g0262.1',
#  'Ppy00g0264.1',
#  'Ppy00g0266.1',
#  'Ppy00g0266.1',
#  'Ppy00g0266.1',
#  'Ppy00g0266.1',
#  'Ppy00g0266.1',
#  'Ppy00g0267.1',
#  'Ppy00g0268.1',
#  'Ppy00g0269.1',
#  'Ppy00g0270.1',
#  'Ppy00g0272.1',
#  'Ppy00g0272.1',
#  'Ppy00g0272.1',
#  'Ppy00g0272.1',
#  'Ppy00g0272.1',
#  'Ppy00g0273.1',
#  'Ppy00g0274.1',
#  'Ppy00g0275.1',
#  'Ppy00g0277.1',
#  'Ppy00g0277.1',
#  'Ppy00g0277.1',
#  'Ppy00g0277.1',
#  'Ppy00g0277.1',
#  'Ppy00g0278.1',
#  'Ppy00g0279.1',
#  'Ppy00g0280.1',
#  'Ppy00g0282.1',
#  'Ppy00g0283.1',
#  'Ppy00g0284.1',
#  'Ppy00g0291.1',
#  'Ppy00g0291.1',
#  'Ppy00g0291.1',
#  'Ppy00g0293.1',
#  'Ppy00g0293.1',
#  'Ppy00g0293.1',
#  'Ppy00g0295.1',
#  'Ppy00g0297.1',
#  'Ppy00g0297.1',
#  'Ppy00g0297.1',
#  'Ppy00g0297.1',
#  'Ppy00g0298.1',
#  'Ppy00g0298.1',
#  'Ppy00g0298.1',
#  'Ppy00g0299.1',
#  'Ppy00g0299.1',
#  'Ppy00g0299.1',
#  'Ppy00g0300.1',
#  'Ppy00g0300.1',
#  'Ppy00g0301.1',
#  'Ppy00g0301.1',
#  'Ppy00g0301.1',
#  'Ppy00g0302.1',
#  'Ppy00g0302.1',
#  'Ppy00g0303.1',
#  'Ppy00g0303.1',
#  'Ppy00g0306.1',
#  'Ppy00g0306.1',
#  'Ppy00g0306.1',
#  'Ppy00g0306.1',
#  'Ppy00g0306.1',
#  'Ppy00g0307.1',
#  'Ppy00g0307.1',
#  'Ppy00g0307.1',
#  'Ppy00g0307.1',
#  'Ppy00g0308.1',
#  'Ppy00g0309.1',
#  'Ppy00g0317.1',
#  'Ppy00g0317.1',
#  'Ppy00g0317.1',
#  'Ppy00g0322.1',
#  'Ppy00g0322.1',
#  'Ppy00g0322.1',
#  'Ppy00g0322.1',
#  'Ppy00g0323.1',
#  'Ppy00g0323.1',
#  'Ppy00g0323.1',
#  'Ppy00g0323.1',
#  'Ppy00g0325.1',
#  'Ppy00g0325.1',
#  'Ppy00g0325.1',
#  'Ppy00g0325.1',
#  'Ppy00g0326.1',
#  'Ppy00g0327.1',
#  'Ppy00g0329.1',
#  'Ppy00g0329.1',
#  'Ppy00g0330.1',
#  'Ppy00g0330.1',
#  'Ppy00g0331.1',
#  'Ppy00g0333.1',
#  'Ppy00g0333.1',
#  'Ppy00g0334.1',
#  'Ppy00g0334.1',
#  'Ppy00g0335.1',
#  'Ppy00g0335.1',
#  'Ppy00g0339.1',
#  'Ppy00g0340.1',
#  'Ppy00g0340.1',
#  'Ppy00g0340.1',
#  'Ppy00g0340.1',
#  'Ppy00g0343.1',
#  'Ppy00g0343.1',
#  'Ppy00g0344.1',
#  'Ppy00g0344.1',
#  'Ppy00g0346.1',
#  'Ppy00g0346.1',
#  'Ppy00g0348.1',
#  'Ppy00g0348.1',
#  'Ppy00g0349.1',
#  'Ppy00g0349.1',
#  'Ppy00g0349.1',
#  'Ppy00g0349.1',
#  'Ppy00g0350.1',
#  'Ppy00g0350.1',
#  'Ppy00g0351.1',
#  'Ppy00g0351.1',
#  'Ppy00g0351.1',
#  'Ppy00g0351.1',
#  'Ppy00g0351.1',
#  'Ppy00g0352.1',
#  'Ppy00g0352.1',
#  'Ppy00g0352.1',
#  'Ppy00g0354.1',
#  'Ppy00g0354.1',
#  'Ppy00g0355.1',
#  'Ppy00g0355.1',
#  'Ppy00g0355.1',
#  'Ppy00g0356.1',
#  'Ppy00g0356.1',
#  'Ppy00g0356.1',
#  'Ppy00g0357.1',
#  'Ppy00g0359.1',
#  'Ppy00g0359.1',
#  'Ppy00g0359.1',
#  'Ppy00g0359.1',
#  'Ppy00g0361.1',
#  'Ppy00g0361.1',
#  'Ppy00g0362.1',
#  'Ppy00g0364.1',
#  'Ppy00g0364.1',
#  'Ppy00g0364.1',
#  'Ppy00g0365.1',
#  'Ppy00g0365.1',
#  'Ppy00g0366.1',
#  'Ppy00g0366.1',
#  'Ppy00g0366.1',
#  'Ppy00g0366.1',
#  'Ppy00g0366.1',
#  'Ppy00g0366.1',
#  'Ppy00g0366.1',
#  'Ppy00g0367.1',
#  'Ppy00g0367.1',
#  'Ppy00g0367.1',
#  'Ppy00g0368.1',
#  'Ppy00g0371.1',
#  'Ppy00g0372.1',
#  'Ppy00g0373.1',
#  'Ppy00g0374.1',
#  'Ppy00g0375.1',
#  'Ppy00g0375.1',
#  'Ppy00g0375.1',
#  'Ppy00g0375.1',
#  'Ppy00g0376.1',
#  'Ppy00g0376.1',
#  'Ppy00g0377.1',
#  'Ppy00g0378.1',
#  'Ppy00g0379.1',
#  'Ppy00g0385.1',
#  'Ppy00g0385.1',
#  'Ppy00g0387.1',
#  'Ppy00g0390.1',
#  'Ppy00g0390.1',
#  'Ppy00g0390.1',
#  'Ppy00g0391.1',
#  'Ppy00g0392.1',
#  'Ppy00g0392.1',
#  'Ppy00g0395.1',
#  'Ppy00g0395.1',
#  'Ppy00g0396.1',
#  'Ppy00g0396.1',
#  'Ppy00g0397.1',
#  'Ppy00g0397.1',
#  'Ppy00g0400.1',
#  'Ppy00g0400.1',
#  'Ppy00g0400.1',
#  'Ppy00g0401.1',
#  'Ppy00g0401.1',
#  'Ppy00g0402.1',
#  'Ppy00g0402.1',
#  'Ppy00g0402.1',
#  'Ppy00g0402.1',
#  'Ppy00g0402.1',
#  'Ppy00g0403.1',
#  'Ppy00g0403.1',
#  'Ppy00g0403.1',
#  'Ppy00g0407.1',
#  'Ppy00g0407.1',
#  'Ppy00g0407.1',
#  'Ppy00g0409.1',
#  'Ppy00g0409.1',
#  'Ppy00g0409.1',
#  'Ppy00g0409.1',
#  'Ppy00g0410.1',
#  'Ppy00g0410.1',
#  'Ppy00g0411.1',
#  'Ppy00g0411.1',
#  'Ppy00g0411.1',
#  'Ppy00g0412.1',
#  'Ppy00g0412.1',
#  'Ppy00g0412.1',
#  'Ppy00g0412.1',
#  'Ppy00g0416.1',
#  'Ppy00g0416.1',
#  'Ppy00g0417.1',
#  'Ppy00g0417.1',
#  'Ppy00g0419.1',
#  'Ppy00g0420.1',
#  'Ppy00g0420.1',
#  'Ppy00g0421.1',
#  'Ppy00g0421.1',
#  'Ppy00g0421.1',
#  'Ppy00g0422.1',
#  'Ppy00g0422.1',
#  'Ppy00g0422.1',
#  'Ppy00g0422.1',
#  'Ppy00g0423.1',
#  'Ppy00g0428.1',
#  'Ppy00g0428.1',
#  'Ppy00g0429.1',
#  'Ppy00g0431.1',
#  'Ppy00g0433.1',
#  'Ppy00g0433.1',
#  'Ppy00g0433.1',
#  'Ppy00g0433.1',
#  'Ppy00g0433.1',
#  'Ppy00g0433.1',
#  'Ppy00g0435.1',
#  'Ppy00g0437.1',
#  'Ppy00g0437.1',
#  'Ppy00g0439.1',
#  'Ppy00g0440.1',
#  'Ppy00g0443.1',
#  'Ppy00g0443.1',
#  'Ppy00g0444.1',
#  'Ppy00g0444.1',
#  'Ppy00g0444.1',
#  'Ppy00g0444.1',
#  'Ppy00g0445.1',
#  'Ppy00g0445.1',
#  'Ppy00g0445.1',
#  'Ppy00g0447.1',
#  'Ppy00g0449.1',
#  'Ppy00g0450.1',
#  'Ppy00g0450.1',
#  'Ppy00g0451.1',
#  'Ppy00g0451.1',
#  'Ppy00g0451.1',
#  'Ppy00g0451.1',
#  'Ppy00g0454.1',
#  'Ppy00g0454.1',
#  'Ppy00g0455.1',
#  'Ppy00g0456.1',
#  'Ppy00g0457.1',
#  'Ppy00g0458.1',
#  'Ppy00g0460.1',
#  'Ppy00g0464.1',
#  'Ppy00g0465.1',
#  'Ppy00g0466.1',
#  'Ppy00g0468.1',
#  'Ppy00g0468.1',
#  'Ppy00g0470.1',
#  'Ppy00g0473.1',
#  'Ppy00g0477.1',
#  'Ppy00g0480.1',
#  'Ppy00g0484.1',
#  'Ppy00g0488.1',
#  'Ppy00g0488.1',
#  'Ppy00g0488.1',
#  'Ppy00g0489.1',
#  'Ppy00g0490.1',
#  'Ppy00g0490.1',
#  'Ppy00g0490.1',
#  'Ppy00g0492.1',
#  'Ppy00g0499.1',
#  'Ppy00g0499.1',
#  'Ppy00g0500.1',
#  'Ppy00g0500.1',
#  'Ppy00g0500.1',
#  'Ppy00g0500.1',
#  'Ppy00g0501.1',
#  'Ppy00g0502.1',
#  'Ppy00g0508.1',
#  'Ppy00g0508.1',
#  'Ppy00g0508.1',
#  'Ppy00g0508.1',
#  'Ppy00g0508.1',
#  'Ppy00g0509.1',
#  'Ppy00g0511.1',
#  'Ppy00g0512.1',
#  'Ppy00g0512.1',
#  'Ppy00g0512.1',
#  'Ppy00g0514.1',
#  'Ppy00g0514.1',
#  'Ppy00g0517.1',
#  'Ppy00g0517.1',
#  'Ppy00g0517.1',
#  'Ppy00g0518.1',
#  'Ppy00g0519.1',
#  'Ppy00g0519.1',
#  'Ppy00g0519.1',
#  'Ppy00g0519.1',
#  'Ppy00g0519.1',
#  'Ppy00g0519.1',
#  'Ppy00g0519.1',
#  'Ppy00g0520.1',
#  'Ppy00g0520.1',
#  'Ppy00g0520.1',
#  'Ppy00g0520.1',
#  'Ppy00g0521.1',
#  'Ppy00g0521.1',
#  'Ppy00g0521.1',
#  'Ppy00g0522.1',
#  'Ppy00g0522.1',
#  'Ppy00g0523.1',
#  'Ppy00g0523.1',
#  'Ppy00g0528.1',
#  'Ppy00g0528.1',
#  'Ppy00g0529.1',
#  'Ppy00g0530.1',
#  'Ppy00g0530.1',
#  'Ppy00g0530.1',
#  'Ppy00g0530.1',
#  'Ppy00g0531.1',
#  'Ppy00g0533.1',
#  'Ppy00g0535.1',
#  'Ppy00g0536.1',
#  'Ppy00g0538.1',
#  'Ppy00g0541.1',
#  'Ppy00g0542.1',
#  'Ppy00g0544.1',
#  'Ppy00g0546.1',
#  'Ppy00g0546.1',
#  'Ppy00g0547.1',
#  'Ppy00g0547.1',
#  'Ppy00g0547.1',
#  'Ppy00g0547.1',
#  'Ppy00g0548.1',
#  'Ppy00g0550.1',
#  'Ppy00g0550.1',
#  'Ppy00g0550.1',
#  'Ppy00g0550.1',
#  'Ppy00g0550.1',
#  'Ppy00g0557.1',
#  'Ppy00g0557.1',
#  'Ppy00g0557.1',
#  'Ppy00g0557.1',
#  'Ppy00g0557.1',
#  'Ppy00g0559.1',
#  'Ppy00g0559.1',
#  'Ppy00g0562.1',
#  'Ppy00g0568.1',
#  'Ppy00g0569.1',
#  'Ppy00g0576.1',
#  'Ppy00g0576.1',
#  'Ppy00g0577.1',
#  'Ppy00g0578.1',
#  'Ppy00g0578.1',
#  'Ppy00g0582.1',
#  'Ppy00g0582.1',
#  'Ppy00g0583.1',
#  'Ppy00g0583.1',
#  'Ppy00g0587.1',
#  'Ppy00g0587.1',
#  'Ppy00g0587.1',
#  'Ppy00g0587.1',
#  'Ppy00g0590.1',
#  'Ppy00g0591.1',
#  'Ppy00g0591.1',
#  'Ppy00g0592.1',
#  'Ppy00g0593.1',
#  'Ppy00g0594.1',
#  'Ppy00g0597.1',
#  'Ppy00g0597.1',
#  'Ppy00g0599.1',
#  'Ppy00g0599.1',
#  'Ppy00g0600.1',
#  'Ppy00g0600.1',
#  'Ppy00g0600.1',
#  'Ppy00g0601.1',
#  'Ppy00g0602.1',
#  'Ppy00g0602.1',
#  'Ppy00g0603.1',
#  'Ppy00g0603.1',
#  'Ppy00g0605.1',
#  'Ppy00g0606.1',
#  'Ppy00g0606.1',
#  'Ppy00g0606.1',
#  'Ppy00g0606.1',
#  'Ppy00g0608.1',
#  'Ppy00g0608.1',
#  'Ppy00g0609.1',
#  'Ppy00g0609.1',
#  'Ppy00g0609.1',
#  'Ppy00g0609.1',
#  'Ppy00g0611.1',
#  'Ppy00g0611.1',
#  'Ppy00g0611.1',
#  'Ppy00g0611.1',
#  'Ppy00g0613.1',
#  'Ppy00g0613.1',
#  'Ppy00g0613.1',
#  'Ppy00g0613.1',
#  'Ppy00g0614.1',
#  'Ppy00g0614.1',
#  'Ppy00g0614.1',
#  'Ppy00g0614.1',
#  'Ppy00g0616.1',
#  'Ppy00g0616.1',
#  'Ppy00g0616.1',
#  'Ppy00g0616.1',
#  'Ppy00g0618.1',
#  'Ppy00g0618.1',
#  'Ppy00g0618.1',
#  'Ppy00g0618.1',
#  'Ppy00g0619.1',
#  'Ppy00g0619.1',
#  'Ppy00g0619.1',
#  'Ppy00g0619.1',
#  'Ppy00g0620.1',
#  'Ppy00g0620.1',
#  'Ppy00g0620.1',
#  'Ppy00g0620.1',
#  'Ppy00g0621.1',
#  'Ppy00g0621.1',
#  'Ppy00g0621.1',
#  'Ppy00g0622.1',
#  'Ppy00g0622.1',
#  'Ppy00g0622.1',
#  'Ppy00g0622.1',
#  'Ppy00g0622.1',
#  'Ppy00g0624.1',
#  'Ppy00g0624.1',
#  'Ppy00g0626.1',
#  'Ppy00g0626.1',
#  'Ppy00g0626.1',
#  'Ppy00g0632.1',
#  'Ppy00g0632.1',
#  'Ppy00g0633.1',
#  'Ppy00g0633.1',
#  'Ppy00g0635.1',
#  'Ppy00g0635.1',
#  'Ppy00g0635.1',
#  'Ppy00g0636.1',
#  'Ppy00g0636.1',
#  'Ppy00g0636.1',
#  'Ppy00g0636.1',
#  'Ppy00g0636.1',
#  'Ppy00g0637.1',
#  'Ppy00g0637.1',
#  'Ppy00g0638.1',
#  'Ppy00g0638.1',
#  'Ppy00g0639.1',
#  'Ppy00g0639.1',
#  'Ppy00g0639.1',
#  'Ppy00g0640.1',
#  'Ppy00g0640.1',
#  'Ppy00g0640.1',
#  'Ppy00g0643.1',
#  'Ppy00g0643.1',
#  'Ppy00g0643.1',
#  'Ppy00g0643.1',
#  'Ppy00g0644.1',
#  'Ppy00g0644.1',
#  'Ppy00g0644.1',
#  'Ppy00g0644.1',
#  'Ppy00g0644.1',
#  'Ppy00g0644.1',
#  'Ppy00g0644.1',
#  'Ppy00g0644.1',
#  'Ppy00g0645.1',
#  'Ppy00g0645.1',
#  'Ppy00g0645.1',
#  'Ppy00g0648.1',
#  'Ppy00g0648.1',
#  'Ppy00g0648.1',
#  'Ppy00g0648.1',
#  'Ppy00g0651.1',
#  'Ppy00g0651.1',
#  'Ppy00g0652.1',
#  'Ppy00g0655.1',
#  'Ppy00g0655.1',
#  'Ppy00g0655.1',
#  'Ppy00g0655.1',
#  'Ppy00g0658.1',
#  'Ppy00g0658.1',
#  'Ppy00g0660.1',
#  'Ppy00g0660.1',
#  'Ppy00g0660.1',
#  'Ppy00g0660.1',
#  'Ppy00g0660.1',
#  'Ppy00g0660.1',
#  'Ppy00g0665.1',
#  'Ppy00g0665.1',
#  'Ppy00g0665.1',
#  'Ppy00g0665.1',
#  'Ppy00g0666.1',
#  'Ppy00g0668.1',
#  'Ppy00g0668.1',
#  'Ppy00g0668.1',
#  'Ppy00g0668.1',
#  'Ppy00g0670.1',
#  'Ppy00g0671.1',
#  'Ppy00g0671.1',
#  'Ppy00g0672.1',
#  'Ppy00g0673.1',
#  'Ppy00g0674.1',
#  'Ppy00g0675.1',
#  'Ppy00g0676.1',
#  'Ppy00g0677.1',
#  'Ppy00g0677.1',
#  'Ppy00g0677.1',
#  'Ppy00g0677.1',
#  'Ppy00g0677.1',
#  'Ppy00g0677.1',
#  'Ppy00g0679.1',
#  'Ppy00g0679.1',
#  'Ppy00g0679.1',
#  'Ppy00g0682.1',
#  'Ppy00g0684.1',
#  'Ppy00g0684.1',
#  'Ppy00g0684.1',
#  'Ppy00g0685.1',
#  'Ppy00g0685.1',
#  'Ppy00g0694.1',
#  'Ppy00g0695.1',
#  'Ppy00g0696.1',
#  'Ppy00g0696.1',
#  'Ppy00g0696.1',
#  'Ppy00g0696.1',
#  'Ppy00g0697.1',
#  'Ppy00g0697.1',
#  'Ppy00g0697.1',
#  'Ppy00g0697.1',
#  'Ppy00g0697.1',
#  'Ppy00g0698.1',
#  'Ppy00g0698.1',
#  'Ppy00g0698.1',
#  'Ppy00g0699.1',
#  'Ppy00g0701.1',
#  'Ppy00g0701.1',
#  'Ppy00g0702.1',
#  'Ppy00g0702.1',
#  'Ppy00g0702.1',
#  'Ppy00g0703.1',
#  'Ppy00g0703.1',
#  'Ppy00g0704.1',
#  'Ppy00g0704.1',
#  'Ppy00g0705.1',
#  'Ppy00g0706.1',
#  'Ppy00g0706.1',
#  'Ppy00g0706.1',
#  'Ppy00g0707.1',
#  'Ppy00g0708.1',
#  'Ppy00g0709.1',
#  'Ppy00g0709.1',
#  'Ppy00g0709.1',
#  'Ppy00g0710.1',
#  'Ppy00g0711.1',
#  'Ppy00g0711.1',
#  'Ppy00g0712.1',
#  'Ppy00g0712.1',
#  'Ppy00g0713.1',
#  'Ppy00g0713.1',
#  'Ppy00g0713.1',
#  'Ppy00g0714.1',
#  'Ppy00g0714.1',
#  'Ppy00g0716.1',
#  'Ppy00g0717.1',
#  'Ppy00g0717.1',
#  'Ppy00g0717.1',
#  'Ppy00g0717.1',
#  'Ppy00g0717.1',
#  'Ppy00g0717.1',
#  'Ppy00g0722.1',
#  'Ppy00g0723.1',
#  'Ppy00g0723.1',
#  'Ppy00g0723.1',
#  'Ppy00g0723.1',
#  'Ppy00g0728.1',
#  'Ppy00g0728.1',
#  'Ppy00g0728.1',
#  'Ppy00g0729.1',
#  'Ppy00g0729.1',
#  'Ppy00g0729.1',
#  'Ppy00g0729.1',
#  'Ppy00g0730.1',
#  'Ppy00g0730.1',
#  'Ppy00g0731.1',
#  'Ppy00g0731.1',
#  'Ppy00g0733.1',
#  'Ppy00g0733.1',
#  'Ppy00g0734.1',
#  'Ppy00g0735.1',
#  'Ppy00g0738.1',
#  'Ppy00g0738.1',
#  'Ppy00g0739.1',
#  'Ppy00g0739.1',
#  'Ppy00g0739.1',
#  'Ppy00g0740.1',
#  'Ppy00g0741.1',
#  'Ppy00g0741.1',
#  'Ppy00g0743.1',
#  'Ppy00g0743.1',
#  'Ppy00g0745.1',
#  'Ppy00g0747.1',
#  'Ppy00g0748.1',
#  'Ppy00g0748.1',
#  'Ppy00g0748.1',
#  'Ppy00g0748.1',
#  'Ppy00g0748.1',
#  'Ppy00g0748.1',
#  'Ppy00g0752.1',
#  'Ppy00g0752.1',
#  'Ppy00g0753.1',
#  'Ppy00g0755.1',
#  'Ppy00g0758.1',
#  'Ppy00g0758.1',
#  'Ppy00g0758.1',
#  'Ppy00g0759.1',
#  'Ppy00g0760.1',
#  'Ppy00g0760.1',
#  'Ppy00g0760.1',
#  'Ppy00g0762.1',
#  'Ppy00g0763.1',
#  'Ppy00g0764.1',
#  'Ppy00g0764.1',
#  'Ppy00g0764.1',
#  'Ppy00g0766.1',
#  'Ppy00g0767.1',
#  'Ppy00g0767.1',
#  'Ppy00g0767.1',
#  'Ppy00g0767.1',
#  'Ppy00g0767.1',
#  'Ppy00g0770.1',
#  'Ppy00g0770.1',
#  'Ppy00g0771.1',
#  'Ppy00g0771.1',
#  'Ppy00g0771.1',
#  'Ppy00g0771.1',
#  'Ppy00g0772.1',
#  'Ppy00g0777.1',
#  'Ppy00g0777.1',
#  'Ppy00g0777.1',
#  'Ppy00g0777.1',
#  'Ppy00g0780.1',
#  'Ppy00g0780.1',
#  'Ppy00g0784.1',
#  'Ppy00g0784.1',
#  'Ppy00g0785.1',
#  'Ppy00g0787.1',
#  'Ppy00g0787.1',
#  'Ppy00g0787.1',
#  'Ppy00g0787.1',
#  'Ppy00g0788.1',
#  'Ppy00g0789.1',
#  'Ppy00g0789.1',
#  'Ppy00g0789.1',
#  'Ppy00g0791.1',
#  'Ppy00g0791.1',
#  'Ppy00g0793.1',
#  'Ppy00g0793.1',
#  'Ppy00g0793.1',
#  'Ppy00g0793.1',
#  'Ppy00g0793.1',
#  'Ppy00g0794.1',
#  'Ppy00g0794.1',
#  'Ppy00g0795.1',
#  'Ppy00g0795.1',
#  'Ppy00g0795.1',
#  'Ppy00g0796.1',
#  'Ppy00g0796.1',
#  'Ppy00g0796.1',
#  'Ppy00g0796.1',
#  'Ppy00g0796.1',
#  'Ppy00g0796.1',
#  'Ppy00g0797.1',
#  'Ppy00g0798.1',
#  'Ppy00g0798.1',
#  'Ppy00g0799.1',
#  'Ppy00g0801.1',
#  'Ppy00g0801.1',
#  'Ppy00g0801.1',
#  'Ppy00g0801.1',
#  'Ppy00g0807.1',
#  ...]

# %%
excel_gene2go.index = gene_id

# %%
genes_query = ["Ppy00g0034.1","Ppy00g0042.1","Ppy00g0040.1"]

# %%
excel_gene2go.loc[genes_query]
# Out:
#                           Query       Match                  GO  \
# Ppy00g0034.1  Ppy00g0034.1_v1.0  GO:0003676  Molecular Function
# Ppy00g0042.1  Ppy00g0042.1_v1.0  GO:0003677  Molecular Function
# Ppy00g0042.1  Ppy00g0042.1_v1.0  GO:0006355  Biological Process
# Ppy00g0040.1  Ppy00g0040.1_v1.0  GO:0003676  Molecular Function
# Ppy00g0040.1  Ppy00g0040.1_v1.0  GO:0004386  Molecular Function
# Ppy00g0040.1  Ppy00g0040.1_v1.0  GO:0005524  Molecular Function
#
#                                                     Term
# Ppy00g0034.1                        nucleic acid binding
# Ppy00g0042.1                                 DNA binding
# Ppy00g0042.1  regulation of transcription, DNA-templated
# Ppy00g0040.1                        nucleic acid binding
# Ppy00g0040.1                           helicase activity
# Ppy00g0040.1                                 ATP binding

# %% [markdown]
# # 이 이후는 직접 해보기 입니다.
# Gene ID를 맞출 수 있는 테이블을 이용해서
# DE_modified 에서 DEG들의 GO를 확인해보세요
#
# <code>ID_PPY = pd.read_excel("ID_PPY_DATA.xlsx")</code>

# %%
ID_PPY
# Out:
#                Gene               ID
# 0      Ppy00g1713.1   nbis-gene-1713
# 1      Ppy00g1714.1   nbis-gene-1714
# 2      Ppy00g1715.1   nbis-gene-1715
# 3      Ppy00g1716.1   nbis-gene-1716
# 4      Ppy00g1717.1   nbis-gene-1717
# ...             ...              ...
# 44871  Ppy17g2631.1  nbis-gene-44872
# 44872  Ppy17g2632.1  nbis-gene-44873
# 44873  Ppy17g2633.1  nbis-gene-44874
# 44874  Ppy17g2634.1  nbis-gene-44875
# 44875  Ppy17g2635.1  nbis-gene-44876
#
# [44876 rows x 2 columns]

# %%
DE_modified[DE_modified["Threshold"] == "DOWN"]
# Out:
#                      sampleA     sampleB     logFC    logCPM        PValue  \
# nbis-gene-37235  Blackblight  Fireblight -2.374873  5.366200  1.345069e-11
# nbis-gene-18755  Blackblight  Fireblight -6.050585  7.204897  3.354682e-11
# nbis-gene-25027  Blackblight  Fireblight -4.398183 -1.394791  1.021102e-10
# nbis-gene-4356   Blackblight  Fireblight -1.930094  6.391506  1.045660e-10
# nbis-gene-21473  Blackblight  Fireblight -2.458743  5.662868  1.631979e-10
# ...                      ...         ...       ...       ...           ...
# nbis-gene-21677  Blackblight  Fireblight -1.125321  4.153602  5.880155e-03
# nbis-gene-25798  Blackblight  Fireblight -1.702472  0.645199  5.887512e-03
# nbis-gene-17991  Blackblight  Fireblight -1.952302  2.458401  5.919579e-03
# nbis-gene-39955  Blackblight  Fireblight -1.337488  0.443098  5.919976e-03
# nbis-gene-44688  Blackblight  Fireblight -2.050904  2.663010  5.945886e-03
#
#                           FDR Threshold   -logFDR
# nbis-gene-37235  4.063184e-07      DOWN  6.391133
# nbis-gene-18755  5.066912e-07      DOWN  6.295257
# nbis-gene-25027  7.896827e-07      DOWN  6.102547
# nbis-gene-4356   7.896827e-07      DOWN  6.102547
# nbis-gene-21473  9.859762e-07      DOWN  6.006134
# ...                       ...       ...       ...
# nbis-gene-21677  4.946469e-02      DOWN  1.305705
# nbis-gene-25798  4.946478e-02      DOWN  1.305704
# nbis-gene-17991  4.964759e-02      DOWN  1.304102
# nbis-gene-39955  4.964759e-02      DOWN  1.304102
# nbis-gene-44688  4.978160e-02      DOWN  1.302931
#
# [1475 rows x 8 columns]

# %%
 test = DE_modified[DE_modified["Threshold"] == "DOWN"].index

# %%
ID_PPY.index = list(ID_PPY.ID)

# %%
ID_PPY
# Out:
#                          Gene               ID
# nbis-gene-1713   Ppy00g1713.1   nbis-gene-1713
# nbis-gene-1714   Ppy00g1714.1   nbis-gene-1714
# nbis-gene-1715   Ppy00g1715.1   nbis-gene-1715
# nbis-gene-1716   Ppy00g1716.1   nbis-gene-1716
# nbis-gene-1717   Ppy00g1717.1   nbis-gene-1717
# ...                       ...              ...
# nbis-gene-44872  Ppy17g2631.1  nbis-gene-44872
# nbis-gene-44873  Ppy17g2632.1  nbis-gene-44873
# nbis-gene-44874  Ppy17g2633.1  nbis-gene-44874
# nbis-gene-44875  Ppy17g2634.1  nbis-gene-44875
# nbis-gene-44876  Ppy17g2635.1  nbis-gene-44876
#
# [44876 rows x 2 columns]

# %%
test
# Out:
# Index(['nbis-gene-37235', 'nbis-gene-18755', 'nbis-gene-25027',
#        'nbis-gene-4356', 'nbis-gene-21473', 'nbis-gene-36623',
#        'nbis-gene-18599', 'nbis-gene-40111', 'nbis-gene-37989',
#        'nbis-gene-22768',
#        ...
#        'nbis-gene-27887', 'nbis-gene-30167', 'nbis-gene-25294',
#        'nbis-gene-13651', 'nbis-gene-18802', 'nbis-gene-21677',
#        'nbis-gene-25798', 'nbis-gene-17991', 'nbis-gene-39955',
#        'nbis-gene-44688'],
#       dtype='object', length=1475)

# %%
tet= list(ID_PPY.loc[test].Gene)

# %%
target = set(excel_gene2go.index) & set(ID_PPY.loc[test].Gene)

# %%
excel_gene2go.loc[target]
# Out:
# /tmp/ipykernel_1704538/2263603207.py:1: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   excel_gene2go.loc[target]
#                           Query       Match                  GO  \
# Ppy11g1589.1  Ppy11g1589.1_v1.0  GO:0055114  Biological Process
# Ppy03g1991.1  Ppy03g1991.1_v1.0  GO:0055114  Biological Process
# Ppy01g0654.1  Ppy01g0654.1_v1.0  GO:0005515  Molecular Function
# Ppy03g0466.1  Ppy03g0466.1_v1.0  GO:0043531  Molecular Function
# Ppy02g1303.1  Ppy02g1303.1_v1.0  GO:0003677  Molecular Function
# ...                         ...         ...                 ...
# Ppy11g0972.1  Ppy11g0972.1_v1.0  GO:0006355  Biological Process
# Ppy10g1820.1  Ppy10g1820.1_v1.0  GO:0004672  Molecular Function
# Ppy10g1820.1  Ppy10g1820.1_v1.0  GO:0005524  Molecular Function
# Ppy10g1820.1  Ppy10g1820.1_v1.0  GO:0006468  Biological Process
# Ppy10g1820.1  Ppy10g1820.1_v1.0  GO:0048544  Biological Process
#
#                                                     Term
# Ppy11g1589.1                 oxidation-reduction process
# Ppy03g1991.1                 oxidation-reduction process
# Ppy01g0654.1                             protein binding
# Ppy03g0466.1                                 ADP binding
# Ppy02g1303.1                                 DNA binding
# ...                                                  ...
# Ppy11g0972.1  regulation of transcription, DNA-templated
# Ppy10g1820.1                     protein kinase activity
# Ppy10g1820.1                                 ATP binding
# Ppy10g1820.1                     protein phosphorylation
# Ppy10g1820.1                       recognition of pollen
#
# [2329 rows x 4 columns]

# %%
last = excel_gene2go.loc[target]
# Out:
# /tmp/ipykernel_1704538/2100691146.py:1: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   last = excel_gene2go.loc[target]

# %%
last[last["GO"] == "Biological Process"]
# Out:
#                           Query       Match                  GO  \
# Ppy11g1589.1  Ppy11g1589.1_v1.0  GO:0055114  Biological Process
# Ppy03g1991.1  Ppy03g1991.1_v1.0  GO:0055114  Biological Process
# Ppy01g1014.1  Ppy01g1014.1_v1.0  GO:0007018  Biological Process
# Ppy06g0455.1  Ppy06g0455.1_v1.0  GO:0006629  Biological Process
# Ppy07g0650.1  Ppy07g0650.1_v1.0  GO:0016126  Biological Process
# ...                         ...         ...                 ...
# Ppy08g2241.1  Ppy08g2241.1_v1.0  GO:0006468  Biological Process
# Ppy12g0081.1  Ppy12g0081.1_v1.0  GO:0006355  Biological Process
# Ppy11g0972.1  Ppy11g0972.1_v1.0  GO:0006355  Biological Process
# Ppy10g1820.1  Ppy10g1820.1_v1.0  GO:0006468  Biological Process
# Ppy10g1820.1  Ppy10g1820.1_v1.0  GO:0048544  Biological Process
#
#                                                     Term
# Ppy11g1589.1                 oxidation-reduction process
# Ppy03g1991.1                 oxidation-reduction process
# Ppy01g1014.1                  microtubule-based movement
# Ppy06g0455.1                     lipid metabolic process
# Ppy07g0650.1                 sterol biosynthetic process
# ...                                                  ...
# Ppy08g2241.1                     protein phosphorylation
# Ppy12g0081.1  regulation of transcription, DNA-templated
# Ppy11g0972.1  regulation of transcription, DNA-templated
# Ppy10g1820.1                     protein phosphorylation
# Ppy10g1820.1                       recognition of pollen
#
# [738 rows x 4 columns]

# %% [markdown]
# # 다음주에는 Python으로 visualization을 하는 방법과 본격적으로 matrix를 다루려 합니다.

# %% [markdown]
# # 3. ML
